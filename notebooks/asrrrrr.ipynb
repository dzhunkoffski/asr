# %%
# !git clone https://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@github.com/dzhunkoffski/asr.git

# %%
# !pip install -r /kaggle/working/asr/requirements.txt

# %%
import os

os.environ['WANDB_API_KEY'] = '3dbf6bc6ee9d845aeb9d49a5be8ef71e8c9fc466'

# %%
# !wget https://us.openslr.org/resources/11/3-gram.arpa.gz

# %%
# !mkdir /kaggle/working/asr/hw_asr/text_encoder/language_models

# %%
# !gunzip -c 3-gram.arpa.gz > /kaggle/working/asr/hw_asr/text_encoder/language_models/3-gram.arpa

# %%
# !pip install editdistance

# %%
# !pip install torch-audiomentations

# %%
# !pip install pyctcdecode

# %%
# !pip install speechbrain

# %%
# !pip install https://github.com/kpu/kenlm/archive/master.zip#sha256=4d002dcde70b52d519cafff4dc0008696c40cff1c9184a531b40c7b45905be6b

# %%
# !cd asr ; python train.py --config /kaggle/working/asr/hw_asr/configs/final_config.json
